# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Read the dataset to python environment

# %%
iris_data = pd.read_excel(r'C:\Users\ashwa\Downloads\iris.xls')

# %% [markdown]
# ## 2. Display the columns in the dataset

# %%
iris_data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 3.Calculate the mean of each column of the dataset

# %%
iris_data.mean()
# Out:
# C:\Users\ashwa\AppData\Local\Temp/ipykernel_6636/3459193012.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   iris_data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ## 4.Check for the null values present in the dataset.

# %%
iris_data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# ## 5.Perform meaningful visualizations using the dataset. Bring at least 3 visualizations

# %% [markdown]
# ### Scatter plot to compare between different species based on their sepal and petal measurements

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,1,1)
plt.title('Comparison between species based on Sepal Length and Sepal Width')
sns.scatterplot(x=iris_data['SL'],y=iris_data['SW'],hue=iris_data['Classification'])

plt.subplot(2,1,2)
plt.title('Comparison between species based on Petal Length and Petal Width')
sns.scatterplot(x=iris_data['PL'],y=iris_data['PW'],hue=iris_data['Classification'])
# Out:
# <AxesSubplot:title={'center':'Comparison between species based on Petal Length and Petal Width'}, xlabel='PL', ylabel='PW'>

# %% [markdown]
# ### Boxplot to analyse the data to find the outliers and variation in the data

# %%
length_width = iris_data[['PL','PW','SL','SW']] 
length_width.boxplot()
plt.xlabel('Flower measurements')
plt.ylabel('values')
plt.title("Iris dataset analysis")
plt.show()

# %% [markdown]
# ### Heatmap to find the correlation of features in data

# %%
sns.heatmap(iris_data.corr(), annot=True)
plt.show()

# %% [markdown]
# ### Pairplot to visualise pairwise relationship of every column in the dataset

# %%
sns.pairplot(iris_data)
